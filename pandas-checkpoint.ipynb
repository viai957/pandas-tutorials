# %%
import pandas as pd

# %%
user = pd.read_csv('ratings.csv')
print(user)
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# 5              1     1968     4.0  1425942148
# 6              1     2762     4.5  1425941300
# 7              1     2918     5.0  1425941593
# 8              1     2959     4.0  1425941601
# 9              1     4226     4.0  1425942228
# 10             1     4878     5.0  1425941434
# 11             1     5577     5.0  1425941397
# 12             1    33794     4.0  1425942005
# 13             1    54503     3.5  1425941313
# 14             1    58559     4.0  1425942007
# 15             1    59315     5.0  1425941502
# 16             1    68358     5.0  1425941464
# 17             1    69844     5.0  1425942139
# 18             1    73017     5.0  1425942699
# ...

# %%
user[1000:]
# Out:
#           userId  movieId  rating   timestamp
# 1000          15     3275     2.5  1346007989
# 1001          15     3361     3.0  1346002218
# 1002          15     3362     5.0  1346009407
# 1003          15     3384     4.0  1346008453
# 1004          15     3481     4.0  1346009511
# 1005          15     3504     4.5  1346009363
# 1006          15     3507     4.5  1346009400
# 1007          15     3508     5.0  1346002582
# 1008          15     3527     4.5  1346008266
# 1009          15     3555     0.5  1346002244
# 1010          15     3578     4.0  1346008604
# 1011          15     3654     2.0  1346007981
# 1012          15     3671     5.0  1346016139
# 1013          15     3681     4.5  1346008093
# 1014          15     3703     2.5  1346002572
# 1015          15     3836     4.0  1346008461
# 1016          15     3868     3.5  1346002221
# 1017          15     3996     4.0  1346008209
# 1018          15     4011     4.0  1346009506
# ...

# %%
user["rating"].head(10)
# Out:
# 0    1.0
# 1    4.5
# 2    5.0
# 3    5.0
# 4    5.0
# 5    4.0
# 6    4.5
# 7    5.0
# 8    4.0
# 9    4.0
# Name: rating, dtype: float64

# %%
user[user.rating > 4.4]
# Out:
#           userId  movieId  rating   timestamp
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# 6              1     2762     4.5  1425941300
# 7              1     2918     5.0  1425941593
# 10             1     4878     5.0  1425941434
# 11             1     5577     5.0  1425941397
# 15             1    59315     5.0  1425941502
# 16             1    68358     5.0  1425941464
# 17             1    69844     5.0  1425942139
# 18             1    73017     5.0  1425942699
# 19             1    81834     5.0  1425942133
# 21             1    91542     5.0  1425942618
# 22             1    92439     5.0  1425941424
# 23             1    96821     5.0  1425941382
# 26             1   112552     5.0  1425941336
# 35             2      339     5.0   867041296
# 46             2     1356     5.0   867039288
# ...

# %%
user[user.movieId < 10]
# Out:
#           userId  movieId  rating   timestamp
# 27             2        5     3.0   867039249
# 121            5        7     3.0   949423844
# 204            8        1     4.0  1013443596
# 205            8        7     2.0  1013442976
# 317            9        1     4.5  1073837180
# 641           12        1     4.0   943912205
# 905           15        6     4.0  1346008202
# 1358          20        1     4.0  1368361348
# 1710          24        1     4.0   979869938
# 1711          24        2     3.0   979974023
# 1712          24        6     4.0   979870499
# 2344          25        2     3.0   838419351
# 2382          27        1     3.5  1201213305
# 2805          34        1     3.0  1498760963
# 2806          34        2     3.0  1498761848
# 2807          34        6     4.0  1498761067
# 3122          37        1     3.5  1301635308
# 3337          40        1     4.0   862515453
# 3338          40        5     4.0   862515493
# ...

# %%
user[10:15]
# Out:
#     userId  movieId  rating   timestamp
# 10       1     4878     5.0  1425941434
# 11       1     5577     5.0  1425941397
# 12       1    33794     4.0  1425942005
# 13       1    54503     3.5  1425941313
# 14       1    58559     4.0  1425942007

# %%
rate = pd.read_csv('credits.csv')

# %%
rate.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
ratings = pd.read_csv('ratings.csv', sep = '|')
