# %% [markdown]
# # Intoduction to Pandas

# %% [markdown]
# About the content

# %% [raw]
# Split up into diffrent modules, each focused on specefic features

# %% [raw]
# Bundeled with CSV datasets to use

# %%
import pandas as pd

# %% [markdown]
# calling the module

# %% [markdown]
# Creating A Series Object from A Python List

# %%
ice_cream = ["Chocolate", "Vanilla", "Strawberry", "Rum Raisin"]
pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
lottery = [4, 8, 16, 15, 42]
pd.Series(lottery)
# Out:
# 0     4
# 1     8
# 2    16
# 3    15
# 4    42
# dtype: int64

# %%
registrations = [True, False, False, True, False, True]
pd.Series(registrations)
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
webser = {"Aardvark" : "An animal",
          "Banana" : "A delicious fruit",
          "Cyan" : "A color"
}
pd.Series(webser)
# Out:
# Aardvark            An animal
# Banana      A delicious fruit
# Cyan                  A color
# dtype: object

# %% [markdown]
# # Intro to methods

# %%
prices = [22.99, 86.99, 120.99]
s = pd.Series(prices)

# %%
s.sum()
# Out:
# 230.96999999999997

# %%
s.product()
# Out:
# 241967.91309899997

# %%
s.mean()
# Out:
# 76.99

# %% [markdown]
# # Parameters and Arguments

# %%
#Difficult -Easy,Medium,Hard
#Volume 1 through 10
#Subtitles -Truth/False

# %%
fruits = ["Apple","Oranges","Banana","Pinapple","Melon"]
days = ["Monday","Tuesday","Sunday","Wednasday","Friday"]
pd.Series(fruits)
pd.Series(data = days, index = fruits)
# Out:
# Apple          Monday
# Oranges       Tuesday
# Banana         Sunday
# Pinapple    Wednasday
# Melon          Friday
# dtype: object

# %% [markdown]
# # Import series with the read csv method

# %%
import pandas as pd

# %%
pd.read_csv('data.csv', usecols =['Name'], squeeze = True)
# Out:
# 0                    L. Messi
# 1           Cristiano Ronaldo
# 2                   Neymar Jr
# 3                      De Gea
# 4                K. De Bruyne
# 5                   E. Hazard
# 6                   L. Modrić
# 7                   L. Suárez
# 8                Sergio Ramos
# 9                    J. Oblak
# 10             R. Lewandowski
# 11                   T. Kroos
# 12                   D. Godín
# 13                David Silva
# 14                   N. Kanté
# 15                  P. Dybala
# 16                    H. Kane
# 17               A. Griezmann
# 18              M. ter Stegen
# 19                T. Courtois
# 20            Sergio Busquets
# 21                  E. Cavani
# 22                   M. Neuer
# 23                  S. Agüero
# 24               G. Chiellini
# 25                  K. Mbappé
# 26                   M. Salah
# 27                   Casemiro
# 28               J. Rodríguez
# 29                 L. Insigne
#                  ...
# ...

# %% [markdown]
# we use squeez = true so as to represent the data set as a series rather than the default dataframe

# %%
pd.read_csv("data.csv")
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
import pandas as pd

# %%
fifa = pd.read_csv("data.csv")
fifa.head(10)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...

# %% [markdown]
# using head function displays the first n no of table content

# %%
fifa.tail(10)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18197       18197  246167          D. Holland   18
# 18198       18198  242844          J. Livesey   18
# 18199       18199  244677        M. Baldisimo   18
# 18200       18200  231381            J. Young   18
# 18201       18201  243413            D. Walsh   18
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo          Nationality  \
# 18197  https://cdn.sofifa.org/players/4/19/246167.png  Republic of Ireland
# 18198  https://cdn.sofifa.org/players/4/19/242844.png              England
# 18199  https://cdn.sofifa.org/players/4/19/244677.png               Canada
# 18200  https://cdn.sofifa.org/players/4/19/231381.png             Scotland
# ...

# %% [markdown]
# using tail function in the data set it prints out the last 10 table content of the file

# %%
len(fifa)
# Out:
# 18207

# %% [markdown]
# displays the length of the content index

# %%
type(fifa)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# displays the data type of the content

# %%
dir(fifa)
# Out:
# ['Acceleration',
#  'Age',
#  'Aggression',
#  'Agility',
#  'Balance',
#  'BallControl',
#  'CAM',
#  'CB',
#  'CDM',
#  'CF',
#  'CM',
#  'Club',
#  'Composure',
#  'Crossing',
#  'Curve',
#  'Dribbling',
#  'FKAccuracy',
#  'Finishing',
#  'Flag',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes',
#  'HeadingAccuracy',
#  'Height',
#  'ID',
#  'Interceptions',
#  'Joined',
#  'Jumping',
#  'LAM',
#  'LB',
#  'LCB',
#  'LCM',
#  'LDM',
#  'LF',
#  'LM',
#  'LS',
#  'LW',
#  'LWB',
#  'LongPassing',
#  'LongShots',
#  'Marking',
#  'Name',
#  'Nationality',
#  'Overall',
#  'Penalties',
#  'Photo',
#  'Position',
#  'Positioning',
#  'Potential',
#  'RAM',
#  'RB',
#  'RCB',
#  'RCM',
#  'RDM',
#  'RF',
#  'RM',
#  'RS',
#  'RW',
#  'RWB',
#  'Reactions',
#  'ST',
#  'ShortPassing',
#  'ShotPower',
#  'SlidingTackle',
#  'Special',
#  'SprintSpeed',
#  'Stamina',
#  'StandingTackle',
#  'Strength',
#  'T',
#  'Value',
#  'Vision',
#  'Volleys',
# ...

# %% [markdown]
# Displays all the available atributes

# %%
sorted(fifa)
# Out:
# ['Acceleration',
#  'Age',
#  'Aggression',
#  'Agility',
#  'Balance',
#  'BallControl',
#  'Body Type',
#  'CAM',
#  'CB',
#  'CDM',
#  'CF',
#  'CM',
#  'Club',
#  'Club Logo',
#  'Composure',
#  'Contract Valid Until',
#  'Crossing',
#  'Curve',
#  'Dribbling',
#  'FKAccuracy',
#  'Finishing',
#  'Flag',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes',
#  'HeadingAccuracy',
#  'Height',
#  'ID',
#  'Interceptions',
#  'International Reputation',
#  'Jersey Number',
#  'Joined',
#  'Jumping',
#  'LAM',
#  'LB',
#  'LCB',
#  'LCM',
#  'LDM',
#  'LF',
#  'LM',
#  'LS',
#  'LW',
#  'LWB',
#  'Loaned From',
#  'LongPassing',
#  'LongShots',
#  'Marking',
#  'Name',
#  'Nationality',
#  'Overall',
#  'Penalties',
#  'Photo',
#  'Position',
#  'Positioning',
#  'Potential',
#  'Preferred Foot',
#  'RAM',
#  'RB',
#  'RCB',
#  'RCM',
#  'RDM',
#  'RF',
#  'RM',
#  'RS',
#  'RW',
#  'RWB',
#  'Reactions',
#  'Real Face',
#  'Release Clause',
#  'ST',
# ...

# %% [markdown]
# for more refrences study the documentation

# %% [raw]
# http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.head.html

# %% [markdown]
# # The .sort_values() method

# %%
fifa = pd.read_csv("data.csv", usecols = "Names", squeeze = True)
fifa.sort_values().head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-5b2c9ae2b21a> in <module>()
# ----> 1 fifa = pd.read_csv("data.csv", usecols = "Names", squeeze = True)
#       2 fifa.sort_values().head()
#
# ...

# %%
fifa.sort_values(ascending = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4012c18b392e> in <module>()
# ----> 1 fifa.sort_values(ascending = True)
#
# TypeError: sort_values() missing 1 required positional argument: 'by'
